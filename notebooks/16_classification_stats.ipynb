# %%
from zettelsortierung import DataBase, Classifiers

# %%
db = DataBase()

# %%
manuel_counts = db.get_label_counts(classifier=Classifiers.MANUELL)
for k, v in manuel_counts.most_common():
    print(f"{k:<20}\t{v:<10}")
# Out:
# FRAGEBOGEN          	368
# NWA                 	179
# DWA                 	163
# GARMANN             	159
# ALTENA              	137
# ANON_HAL_BO         	133
# ISERLOHN            	133
# ANON_STF_OC         	128
# BAADER_FB           	128
# SANDEBECK           	128
# BAADER_NL           	125
# AFFERDE             	124
# GRUPE               	123
# HBL_IND             	123
# WESTF_SP_ARCHIV     	121
# ANON_AHS_ST         	114
# SKIPPED             	107
# ZRHWV               	105
# HIAT                	104
# RHEINE              	104
# VORHELM             	104
# KAULINGFRECKS       	103
# WOESTE_WB           	103
# METTINGEN           	102
# NOLDE               	99
# OEKE                	96
# OEL                 	95
# BRINKERS            	93
# DEILINGHOFEN        	91
# FLURNAMEN           	89
# ATLAS_FRGB          	88
# SCHMELZER           	87
# WESTF_VOLKSK        	87
# KOCH_BRACHT         	86
# OESTRICH_L          	86
# ND_JB               	85
# WAL_RO              	85
# ...

# %%
model_counts = db.get_label_counts(classifier=Classifiers.MODEL_V20083)
for k, v in model_counts.most_common():
    print(f"{k:<20}\t{v:<10}")
# Out:
# FRAGEBOGEN          	265009
# NWA                 	95429
# BAADER_FB           	63062
# DWA                 	56559
# ARCH_RKLH           	32880
# WM_WB               	26795
# WESTF_SP_ARCHIV     	26393
# ECKARDT             	22204
# KLOENTRUP           	20069
# SCHOENING           	18350
# FREDERKING          	14300
# ATLAS_FRGB          	12979
# AHLEN_A             	12763
# WOESTE_WB           	12735
# PHONEM              	11752
# SCHROEDER           	11653
# KOCH_BRACHT         	11059
# WAL_RO              	10812
# OESTERHAUS          	10739
# ISERLOHN            	10564
# METTINGEN           	10427
# VERWEIS             	10129
# ASSINGHAUSEN        	9782
# DITTMAR             	9596
# VORHELM             	9491
# ALTENA              	8598
# PLATENAU_WB         	8315
# WAL_BH              	8167
# OEKE                	8004
# WARSTEIN            	7777
# WESTF_VOLKSK        	7706
# RAKERS              	6830
# HECKSCHER           	6422
# OEL                 	6254
# ...

# %%
ocr_counts = db.get_label_counts(classifier=Classifiers.OCR)
for k, v in ocr_counts.most_common():
    print(f"{k:<20}\t{v:<10}")
# Out:
# ANON_MIN_HA         	12411
# ANON_HAL_BH         	11492
# ANON_BEN_HI         	5855
# ANON_STH_ST         	5630
# ANON_BEK_VH         	4369
# ANON_TEK_ME         	4103
# ANON_MES_BR         	3591
# ANON_LIN_BE         	3483
# ANON_BRI_AH         	3140
# ANON_TEK_LE         	2447
# ANON_ALT_HA         	2405
# ANON_MÜN_MÜ         	2247
# ANON_BRI_NF         	2110
# ANON_REK_KH         	2070
# ANON_AHS_WE         	2042
# ANON_UNN_HI         	1979
# ANON_BEK_AL         	1770
# ANON_BOR_BH         	1721
# ANON_ASD_VR         	1658
# ANON_ISL_IS         	1613
# ANON_ARN_WA         	1518
# ANON_HFD_GO         	1506
# ANON_DOR_WI         	1477
# ANON_SOS_SC         	1434
# ANON_DET_HD         	1408
# ANON_ARN_MÜ         	1399
# ANON_LST_DR         	1392
# ANON_REK_RH         	1363
# ANON_LST_GE         	1358
# ANON_DOR_WL         	1354
# ANON_BBR_WE         	1331
# ANON_REK_BO         	1319
# ANON_DET_IS         	1318
# ANON_HAG_HG         	1305
# ANON_ENR_HO         	1266
# ...
